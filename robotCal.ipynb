# %%
from calUtils import *
from scipy.optimize import least_squares, minimize

# %%
file_num = 18
folder = 'iProbeCalibration/geoCalRobot3'
def err_iprobe(iprobe_prm_input, solidCube_prm_input, mode):
    return getError_robot(Prm(iprobe_prm_input[0], 
                        iprobe_prm_input[1], 
                        iprobe_prm_input[2]), 
                    solidCube(solidCube_prm_input[0], 
                              solidCube_prm_input[1], 
                              solidCube_prm_input[2], 
                              solidCube_prm_input[3], 
                              solidCube_prm_input[4], 
                              solidCube_prm_input[5]), 
                    mode, file_num, folder)
    
def err_solidcube(solidCube_prm_input, iprobe_prm_input, mode):
    return getError_robot(Prm(iprobe_prm_input[0], 
                        iprobe_prm_input[1], 
                        iprobe_prm_input[2]), 
                    solidCube(solidCube_prm_input[0], 
                              solidCube_prm_input[1], 
                              solidCube_prm_input[2], 
                              solidCube_prm_input[3], 
                              solidCube_prm_input[4], 
                              solidCube_prm_input[5]), 
                    mode, file_num, folder)

# %%
def iterative_optimization(iprobe_prm_input, solidCube_prm_input, 
                           tol=1e-6, max_iter=1000):
    prev_error = np.inf
    for iteration in range(max_iter):
        result_iprobe = minimize(fun=err_iprobe, 
                                 x0=iprobe_prm_input, 
                                 args=(solidCube_prm_input, 'scalar'), 
                                 method='L-BFGS-B', 
                                 bounds=[(53.5, 73.5), 
                                         (67.0, 87.0), 
                                         (-87.0, -67.0)], 
                                 tol=tol,
                                 options={'maxiter': max_iter, 'disp': False})
        iprobe_prm_input = result_iprobe.x
        
        result_solidCube = least_squares(fun=err_solidcube, 
                                         x0=solidCube_prm_input, 
                                         args=(iprobe_prm_input, 'vector'), 
                                         ftol=tol, 
                                         # tr_options={'verbosity': 1, 'max_iter': 2000}, 
                                         verbose=1, 
                                         max_nfev=max_iter)
        solidCube_prm_input = result_solidCube.x
        
        current_error = err_iprobe(iprobe_prm_input, solidCube_prm_input, 'scalar')
        print(f"Iteration {iteration+1}, Error: {current_error:.8f}")
        if abs(prev_error - current_error) < tol:
            print("Converged.")
            break
        elif current_error >= prev_error:
            print("Converged.")
            return prev_iprobe_prm, prev_solidCube_prm, prev_error
        prev_error = current_error
        prev_iprobe_prm = iprobe_prm_input
        prev_solidCube_prm = solidCube_prm_input
    
    return iprobe_prm_input, solidCube_prm_input, current_error

# %%
iprobe_prm_input = [63.5, 77.0, -77.0]
solidCube_prm_input = [-2.2266e-03, 6.3928e-02, -5.1277e-05, 
                       5.4682e+00, 7.0481e-04, 4.8222e-04]
# iprobe_prm_input = [66.20844612, 74.07940723, -77.77190349]
# solidCube_prm_input = [5.75713355e-03, 1.65454347e-01, -2.51927934e-03, 
#                        5.47618023e+00, 6.33467621e-02, -4.00017302e-04]
# iprobe_prm_input = [65.39392092546034, 74.27754179794745, -78.90018349612558]
# solidCube_prm_input = [0.026621052826668653, 0.28142488671966015, -0.003442528937855944, 
#                        5.497038874449061, 0.004936267489441483, -0.0005406968424569496]

print(f"Before calibration: {err_iprobe(iprobe_prm_input, solidCube_prm_input, 'scalar')}")
final_iprobe_prm, final_solidCube_prm, final_error = iterative_optimization(iprobe_prm_input, solidCube_prm_input)

print("\nFinal optimized parameters:")
print(f"iProbe Parameters: [{final_iprobe_prm[0]}, {final_iprobe_prm[1]}, {final_iprobe_prm[2]}]")
print(f"SolidCube Parameters: [{final_solidCube_prm[0]}, {final_solidCube_prm[1]}, {final_solidCube_prm[2]}, {final_solidCube_prm[3]}, {final_solidCube_prm[4]}, {final_solidCube_prm[5]}]")
print("Final Error:", final_error)
# Out:
# Before calibration: 4.112481225581502
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 2.5693e+00, final cost 1.8076e+00, first-order optimality 1.27e+00.
# Iteration 1, Error: 1.90136010
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 1.7017e+00, final cost 1.6620e+00, first-order optimality 1.35e+00.
# Iteration 2, Error: 1.82318968
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 1.6538e+00, final cost 1.6399e+00, first-order optimality 1.38e+00.
# Iteration 3, Error: 1.81103937
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 1.6392e+00, final cost 1.5339e+00, first-order optimality 3.42e+00.
# Iteration 4, Error: 1.75153208
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 1.5190e+00, final cost 1.4887e+00, first-order optimality 3.73e+00.
# Iteration 5, Error: 1.72553990
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 1.4879e+00, final cost 1.3997e+00, first-order optimality 5.31e-01.
# Iteration 6, Error: 1.67312260
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3994e+00, final cost 1.3994e+00, first-order optimality 5.88e-01.
# Iteration 7, Error: 1.67293764
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.3993e+00, final cost 1.3977e+00, first-order optimality 5.63e-01.
# Iteration 8, Error: 1.67192621
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.3977e+00, final cost 1.3976e+00, first-order optimality 1.43e-01.
# Iteration 9, Error: 1.67191457
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3976e+00, final cost 1.3973e+00, first-order optimality 1.83e-01.
# Iteration 10, Error: 1.67172285
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3973e+00, final cost 1.3969e+00, first-order optimality 7.53e-01.
# Iteration 11, Error: 1.67145493
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3969e+00, final cost 1.3966e+00, first-order optimality 3.82e-01.
# Iteration 12, Error: 1.67126677
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3966e+00, final cost 1.3964e+00, first-order optimality 1.10e-01.
# Iteration 13, Error: 1.67115923
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3964e+00, final cost 1.3962e+00, first-order optimality 8.36e-02.
# Iteration 14, Error: 1.67107713
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3962e+00, final cost 1.3962e+00, first-order optimality 2.70e-01.
# Iteration 15, Error: 1.67103931
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3962e+00, final cost 1.3960e+00, first-order optimality 2.96e-01.
# Iteration 16, Error: 1.67094997
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3960e+00, final cost 1.3960e+00, first-order optimality 3.83e-01.
# Iteration 17, Error: 1.67091475
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3960e+00, final cost 1.3956e+00, first-order optimality 1.76e-01.
# Iteration 18, Error: 1.67070135
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3956e+00, final cost 1.3952e+00, first-order optimality 2.20e-01.
# Iteration 19, Error: 1.67044611
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3952e+00, final cost 1.3949e+00, first-order optimality 1.45e-01.
# Iteration 20, Error: 1.67027166
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3949e+00, final cost 1.3944e+00, first-order optimality 2.52e-01.
# Iteration 21, Error: 1.66998388
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3944e+00, final cost 1.3943e+00, first-order optimality 1.32e-01.
# Iteration 22, Error: 1.66989875
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3943e+00, final cost 1.3942e+00, first-order optimality 3.01e-01.
# Iteration 23, Error: 1.66983553
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3942e+00, final cost 1.3941e+00, first-order optimality 2.02e-01.
# Iteration 24, Error: 1.66979295
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3941e+00, final cost 1.3941e+00, first-order optimality 7.71e-02.
# Iteration 25, Error: 1.66976133
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.3941e+00, final cost 1.3927e+00, first-order optimality 2.87e-01.
# Iteration 26, Error: 1.66897079
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3927e+00, final cost 1.3915e+00, first-order optimality 1.54e-01.
# Iteration 27, Error: 1.66824207
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3915e+00, final cost 1.3910e+00, first-order optimality 3.55e-01.
# Iteration 28, Error: 1.66792612
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3910e+00, final cost 1.3909e+00, first-order optimality 1.92e-01.
# Iteration 29, Error: 1.66785579
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3909e+00, final cost 1.3908e+00, first-order optimality 1.12e-01.
# Iteration 30, Error: 1.66781343
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3908e+00, final cost 1.3907e+00, first-order optimality 9.37e-02.
# Iteration 31, Error: 1.66773578
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3907e+00, final cost 1.3906e+00, first-order optimality 2.80e-01.
# Iteration 32, Error: 1.66769681
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3906e+00, final cost 1.3905e+00, first-order optimality 5.25e-01.
# Iteration 33, Error: 1.66761104
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3905e+00, final cost 1.3904e+00, first-order optimality 2.69e-01.
# Iteration 34, Error: 1.66757503
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3904e+00, final cost 1.3902e+00, first-order optimality 1.46e-01.
# Iteration 35, Error: 1.66743049
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3902e+00, final cost 1.3896e+00, first-order optimality 1.94e-01.
# Iteration 36, Error: 1.66712064
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3896e+00, final cost 1.3895e+00, first-order optimality 2.16e-01.
# Iteration 37, Error: 1.66704539
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3895e+00, final cost 1.3895e+00, first-order optimality 1.68e-01.
# Iteration 38, Error: 1.66700534
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3895e+00, final cost 1.3893e+00, first-order optimality 8.55e-02.
# Iteration 39, Error: 1.66692067
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3893e+00, final cost 1.3892e+00, first-order optimality 3.06e-01.
# Iteration 40, Error: 1.66686337
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3892e+00, final cost 1.3891e+00, first-order optimality 8.82e-02.
# Iteration 41, Error: 1.66681862
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3891e+00, final cost 1.3890e+00, first-order optimality 2.36e-01.
# Iteration 42, Error: 1.66675129
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3890e+00, final cost 1.3890e+00, first-order optimality 2.64e-01.
# Iteration 43, Error: 1.66670893
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3890e+00, final cost 1.3889e+00, first-order optimality 1.28e-01.
# Iteration 44, Error: 1.66667837
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 1.3889e+00, final cost 1.3711e+00, first-order optimality 7.90e-01.
# Iteration 45, Error: 1.65596592
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 1.3704e+00, final cost 1.3668e+00, first-order optimality 1.02e+00.
# Iteration 46, Error: 1.65334445
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.3667e+00, final cost 1.3547e+00, first-order optimality 2.56e-01.
# Iteration 47, Error: 1.64602723
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3546e+00, final cost 1.3495e+00, first-order optimality 3.48e-01.
# Iteration 48, Error: 1.64283898
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3493e+00, final cost 1.3471e+00, first-order optimality 2.13e-01.
# Iteration 49, Error: 1.64142480
# `ftol` termination condition is satisfied.
# Function evaluations 19, initial cost 1.3471e+00, final cost 1.3460e+00, first-order optimality 1.71e-01.
# Iteration 50, Error: 1.64073560
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3460e+00, final cost 1.3455e+00, first-order optimality 2.49e-01.
# Iteration 51, Error: 1.64045347
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3455e+00, final cost 1.3454e+00, first-order optimality 6.61e-01.
# Iteration 52, Error: 1.64035375
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.3454e+00, final cost 1.3448e+00, first-order optimality 1.05e-01.
# Iteration 53, Error: 1.63999040
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3448e+00, final cost 1.3446e+00, first-order optimality 2.19e-01.
# Iteration 54, Error: 1.63987460
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.3446e+00, final cost 1.3445e+00, first-order optimality 2.72e-01.
# Iteration 55, Error: 1.63984637
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3445e+00, final cost 1.3373e+00, first-order optimality 5.39e-01.
# Iteration 56, Error: 1.63544582
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3372e+00, final cost 1.3372e+00, first-order optimality 2.22e-01.
# Iteration 57, Error: 1.63533721
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3372e+00, final cost 1.3358e+00, first-order optimality 1.12e-01.
# Iteration 58, Error: 1.63450098
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 1.3358e+00, final cost 1.3350e+00, first-order optimality 3.61e-01.
# Iteration 59, Error: 1.63400099
# `ftol` termination condition is satisfied.
# Function evaluations 17, initial cost 1.3350e+00, final cost 1.3335e+00, first-order optimality 1.23e-01.
# Iteration 60, Error: 1.63312486
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3335e+00, final cost 1.3335e+00, first-order optimality 1.41e-01.
# Iteration 61, Error: 1.63307013
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.3335e+00, final cost 1.3335e+00, first-order optimality 3.95e-01.
# Iteration 62, Error: 1.63306726
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.3335e+00, final cost 1.3335e+00, first-order optimality 8.88e-02.
# Iteration 63, Error: 1.63306608
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 1.3335e+00, final cost 1.3334e+00, first-order optimality 3.68e-01.
# Iteration 64, Error: 1.63304094
# The maximum number of function evaluations is exceeded.
# Function evaluations 1000, initial cost 1.3334e+00, final cost 1.3132e+00, first-order optimality 1.00e+00.
# Iteration 65, Error: 1.62061679
# `ftol` termination condition is satisfied.
# Function evaluations 18, initial cost 1.3130e+00, final cost 1.2980e+00, first-order optimality 3.85e-01.
# Iteration 66, Error: 1.61122621
# `ftol` termination condition is satisfied.
# Function evaluations 14, initial cost 1.2980e+00, final cost 1.2980e+00, first-order optimality 2.08e-01.
# Iteration 67, Error: 1.61120013
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 1.2980e+00, final cost 1.2980e+00, first-order optimality 3.30e-01.
# Iteration 68, Error: 1.61119928
# Converged.
#
# Final optimized parameters:
# iProbe Parameters: [64.5011708628196, 75.26929508546563, -77.89281550217865]
# SolidCube Parameters: [2.7855151612228064, -0.07886438612558434, 0.0028889278738881566, 8.261248615052335, -0.07499427477443624, 0.0017110750522519528]
# Final Error: 1.6111992777845625

# %%
# test
iprobe_prm_input = [63.5, 77, -77]
solidCube_prm_input = [0, 0, 0, 0, 0, 0]
print(f"Before calibration: {err_iprobe(iprobe_prm_input, solidCube_prm_input, 'scalar')}")

iprobe_prm_input = [64.5011708628196, 75.26929508546563, -77.89281550217865]
solidCube_prm_input = [2.7855151612228064, -0.07886438612558434, 0.0028889278738881566, 
                       8.261248615052335, -0.07499427477443624, 0.0017110750522519528]
print(f"After calibration: {err_iprobe(iprobe_prm_input, solidCube_prm_input, 'scalar')}")
# Out:
# Before calibration: 6.815403738658085
# After calibration: 1.6111992777845625
